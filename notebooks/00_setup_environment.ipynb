# %%
# Cell 1: Environment Check
print("🔧 Environment Setup for Club Piscine MMM")
print("=" * 50)

# Check Python version
import sys
print(f"Python version: {sys.version}")

# Verify package installations
packages = ['pandas', 'numpy', 'matplotlib', 'seaborn', 'yaml', 'openmeteo_requests', 'statsmodels', 'openpyxl','holidays','prophet','xgboost','lightgbm']
missing = []

for pkg in packages:
    try:
        __import__(pkg.replace('-', '_'))
        print(f"✓ {pkg} is installed")
    except ImportError:
        print(f"✗ {pkg} is NOT installed")
        missing.append(pkg)

if missing:
    print(f"\n⚠️ Missing packages: {missing}")
    print("Installing missing packages...")
    import subprocess
    for pkg in missing:
        subprocess.check_call([sys.executable, "-m", "pip", "install", pkg])
else:
    print("\n✅ All required packages are installed!")
# Out:
# 🔧 Environment Setup for Club Piscine MMM
# ==================================================
# Python version: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:09:21) [Clang 14.0.6 ]
# ✓ pandas is installed
# ✓ numpy is installed
# ✓ matplotlib is installed
# ✓ seaborn is installed
# ✓ yaml is installed
# ✓ openmeteo_requests is installed
# ✓ statsmodels is installed
# ✓ openpyxl is installed
# ✓ holidays is installed
# ✓ prophet is installed
# ✓ xgboost is installed
# ✗ lightgbm is NOT installed
#
# ⚠️ Missing packages: ['lightgbm']
# Installing missing packages...
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-macosx_10_15_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/envs/ClubPiscineModel/lib/python3.13/site-packages (from lightgbm) (2.4.1)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/ClubPiscineModel/lib/python3.13/site-packages (from lightgbm) (1.17.0)
# Downloading lightgbm-4.6.0-py3-none-macosx_10_15_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.5 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0

# %%
# Import required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
import statsmodels.api as sm
import openpyxl
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Cell 2: Project Structure Verification
import os
from pathlib import Path

# Define project root
project_root = Path().cwd().parent if Path().cwd().name == 'notebooks' else Path().cwd()
print(f"Project root: {project_root}")

# Check if all required directories exist
required_dirs = [
    'data/raw',
    'data/interim', 
    'data/processed',
    'notebooks',
    'config',
    'src/data',
    'src/features',
    'src/models',
    'src/analysis',
    'reports/figures'
]

print("\n Checking project structure:")
all_good = True
for dir_path in required_dirs:
    full_path = project_root / dir_path
    if full_path.exists():
        print(f"✓ {dir_path}/")
    else:
        print(f"✗ {dir_path}/ (MISSING)")
        all_good = False

if all_good:
    print("\n Project structure is complete")
else:
    print("\n Some directories are missing. Creating them...")
    for dir_path in required_dirs:
        full_path = project_root / dir_path
        full_path.mkdir(parents=True, exist_ok=True)
        print(f"Created: {full_path}")
# Out:
# Project root: /Users/raoul/Dev/busa693-clubpiscine
#
#  Checking project structure:
# ✓ data/raw/
# ✓ data/interim/
# ✓ data/processed/
# ✓ notebooks/
# ✓ config/
# ✓ src/data/
# ✓ src/features/
# ✓ src/models/
# ✓ src/analysis/
# ✓ reports/figures/
#
#  Project structure is complete
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#  List of Raw Data Files
raw_path = project_root / 'data' / 'raw'
print(f" Looking for data files in: {raw_path}")

if raw_path.exists():
    files = list(raw_path.glob('*'))
    if files:
        print(f"Found {len(files)} file(s):")
        for i, file_path in enumerate(files, 1):
            size_kb = file_path.stat().st_size / 1024
            print(f"{i:2}. {file_path.name:40} ({size_kb:.1f} KB)")
            
        # Identifying file types
        print("\n Trying to identify file types:")
        for file_path in files:
            if file_path.suffix.lower() in ['.csv', '.xlsx', '.xls']:
                print(f"\n{file_path.name}:")
                try:
                    if file_path.suffix.lower() == '.csv':
                        # Try different encodings
                        encodings = ['utf-8', 'latin-1', 'ISO-8859-1', 'cp1252']
                        df = None
                        for enc in encodings:
                            try:
                                df = pd.read_csv(file_path, encoding=enc, nrows=5)
                                print(f"  ✓ Can read with {enc} encoding")
                                break
                            except:
                                continue
                        if df is not None:
                            print(f"  Columns: {list(df.columns)}")
                            print(f"  Shape preview: {df.shape}")
                    elif file_path.suffix.lower() in ['.xlsx', '.xls']:
                        df = pd.read_excel(file_path, nrows=5)
                        print(f"  ✓ Can read Excel file")
                        print(f"  Columns: {list(df.columns)}")
                        print(f"  Shape preview: {df.shape}")
                except Exception as e:
                    print(f"  ✗ Error reading: {str(e)[:100]}...")
    else:
        print("No files found in data/raw/")
        print("Please add files to this directory.")
else:
    print("data/raw/ directory doesn't exist!")
# Out:
#  Looking for data files in: /Users/raoul/Dev/busa693-clubpiscine/data/raw
# Found 12 file(s):
#  1. CalendrierFiscal.xlsx                    (349.7 KB)
#  2. Budget 2025 - 21 août.xlsx               (67.6 KB)
#  3. Budget_2023_.xlsx                        (41.7 KB)
#  4. Rapport de soumissions 2025.xlsx         (2117.9 KB)
#  5. ~$Preroll  2025.xlsx                     (0.2 KB)
#  6. Budget 2023 .xlsx                        (42.0 KB)
#  7. Historical sales by store and by division for 2023-2024-2025.xlsx (1057.9 KB)
#  8. Rapport de soumissions 2024.xlsx         (3169.6 KB)
#  9. Recap_Tableau_Medias_2025.xlsx           (200.4 KB)
# 10. Preroll  2025.xlsx                       (5.7 KB)
# 11. Budget 2024 - REEL au 5 novembre.xlsx    (103.9 KB)
# 12. ~$Budget 2023 .xlsx                      (0.2 KB)
#
#  Trying to identify file types:
#
# CalendrierFiscal.xlsx:
#   ✓ Can read Excel file
#   Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2']
#   Shape preview: (5, 3)
#
# Budget 2025 - 21 août.xlsx:
#   ✓ Can read Excel file
#   Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'VERSION', 'BUDGET 2025 - V6', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 19, 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'VERSION.1', 'BUDGET RÉEL 2025', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80', 'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84', 'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91', 'Unnamed: 92', 'Unnamed: 93', 'Unnamed: 94', 'Unnamed: 95', 'Unnamed: 96', 'Unnamed: 97', 'Unnamed: 98', 'Unnamed: 99', 'Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 104', 'Unnamed: 105', '19.1', 'Unnamed: 107', 'Unnamed: 108', 'Unnamed: 109', 'Unnamed: 110', 'Unnamed: 111', 'Unnamed: 112', 'Unnamed: 113', 'Unnamed: 114', 'Unnamed: 115', 'Unnamed: 116', 'Unnamed: 117', 'Unnamed: 118', 'Unnamed: 119', 'Unnamed: 120', 'Unnamed: 121', 'Unnamed: 122', 'Unnamed: 123', 'Unnamed: 124', 'Unnamed: 125', 'Unnamed: 126']
#   Shape preview: (5, 127)
#
# Budget_2023_.xlsx:
#   ✓ Can read Excel file
#   Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'BUDGET 2023 RÉEL', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63']
#   Shape preview: (5, 64)
#
# Rapport de soumissions 2025.xlsx:
#   ✓ Can read Excel file
#   Columns: ['Unnamed: 0', '2025', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', '2024', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 2023, 'Unnamed: 10']
#   Shape preview: (5, 11)
#
# ~$Preroll  2025.xlsx:
#   ✗ Error reading: Excel file format cannot be determined, you must specify an engine manually....
#
# Budget 2023 .xlsx:
#   ✓ Can read Excel file
#   Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'BUDGET 2023 RÉEL', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63']
#   Shape preview: (5, 64)
#
# Historical sales by store and by division for 2023-2024-2025.xlsx:
#   ✓ Can read Excel file
#   Columns: ['please only use columns in light blue', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'HT-Piscine hors-terre', 'HT-Piscine hors-terre.1', 'CR-Piscine creusée', 'CR-Piscine creusée.1', 'SP-Spa', 'SP-Spa.1', 'ME-Meuble', 'GA-Gazebo et Abri', 'ME-Meuble & GA-Gazebo', 'FI-Fitness', 'BQ-BBQ']
#   Shape preview: (5, 16)
#
# Rapport de soumissions 2024.xlsx:
#   ✓ Can read Excel file
#   Columns: ['2024', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 2023, 'Unnamed: 5']
#   Shape preview: (5, 6)
#
# Recap_Tableau_Medias_2025.xlsx:
#   ✓ Can read Excel file
#   Columns: ['Nom de la campagne', 'Date début', 'Date fin', 'Média', 'Partenaire Média', 'Station / Support', '# contrat', 'Marché \n(Province/Ville)', 'Cible principale', 'Autres cibles \n(optionnel)', 'Format & durée', 'Coût total \n($ NET)', 'Nb occasions\n(PRÉVU)', 'Impressions totales\n(PRÉVU)', 'PEB\n(PRÉVU)', 'Portée \n(%)', 'Fréquence moyenne', 'CPP\n(PRÉVU)', 'CPM\n(PRÉVU)', 'Nb occasions\n(RÉEL)', 'Impressions totales \n(RÉEL)', 'PEB\n(RÉEL)', 'Portée \n(RÉEL)', 'Fréquence moyenne (RÉEL)', 'CPP\n(RÉEL)', 'CPM\n(RÉEL)', '% livraison vs contrat', 'VUES COMPLÉTÉES*', 'TAUX DE VUES', 'CLICS (RÉÉL)', 'TAUX CE CLICS', 'Commentaires / Notes']
#   Shape preview: (5, 32)
#
# Preroll  2025.xlsx:
#   ✓ Can read Excel file
#   Columns: ['Preroll - 2025', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
#   Shape preview: (5, 7)
#
# Budget 2024 - REEL au 5 novembre.xlsx:
#   ✓ Can read Excel file
#   Columns: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'BUDGET 2024 APPROUVÉ', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'BUDGET 2024 RÉEL', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79', 'Unnamed: 80', 'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84', 'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91', 'Unnamed: 92', 'Unnamed: 93', 'Unnamed: 94', 'Unnamed: 95', 'Unnamed: 96', 'Unnamed: 97', 'Unnamed: 98', 'Unnamed: 99', 'Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 104', 'Unnamed: 105', 'Unnamed: 106', 'Unnamed: 107', 'Unnamed: 108', 'Unnamed: 109', 'Unnamed: 110', 'Unnamed: 111', 'Unnamed: 112', 'Unnamed: 113', 'Unnamed: 114', 'Unnamed: 115', 'Unnamed: 116', 'Unnamed: 117', 'Unnamed: 118', 'Unnamed: 119', 'Unnamed: 120', 'Unnamed: 121', 'Unnamed: 122', 'Unnamed: 123', 'Unnamed: 124', 'Unnamed: 125', 'Unnamed: 126', 'Unnamed: 127', 'Unnamed: 128', 'Unnamed: 129', 'Unnamed: 130', 'Unnamed: 131', 'Unnamed: 132', 'Unnamed: 133', 'Unnamed: 134', 'Unnamed: 135', 'Unnamed: 136', 'Unnamed: 137', 'Unnamed: 138', 'Unnamed: 139', 'Unnamed: 140', 'Unnamed: 141', 'Unnamed: 142', 'Unnamed: 143', 'Unnamed: 144', 'Unnamed: 145', 'Unnamed: 146', 'Unnamed: 147', 'Unnamed: 148', 'Unnamed: 149', 'Unnamed: 150', 'Unnamed: 151', 'Unnamed: 152', 'Unnamed: 153', 'Unnamed: 154', 'Unnamed: 155', 'Unnamed: 156', 'Unnamed: 157']
#   Shape preview: (5, 158)
#
# ~$Budget 2023 .xlsx:
#   ✗ Error reading: Excel file format cannot be determined, you must specify an engine manually....
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Budget Data Coverage (Updated 2026-02-07)
#
# This notebook automatically detects and processes all budget files in the `data/raw/` directory.
#
# **Current Coverage:**
# - Budget 2023 (Budget_2023_.xlsx) - REEL data through September 2023
# - Budget 2024 (Budget 2024 - REEL au 5 novembre.xlsx) - REEL data through November 2024
# - Budget 2025 (Budget 2025 - 21 août.xlsx) - Budget and REEL data
#
# The file scanning logic above will automatically include any new budget files added to the raw data directory.
